# %%
print(f"I am {44} years old.")
# Out:
# I am 44 years old.

# %%
print(f"There are {365/7} weeks in a year")
# Out:
# There are 52.142857142857146 weeks in a year

# %%
print(f"There are {365/7:.f2} weeks in a year")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(f"There are {365/7:.f2} weeks in a year")
#
# ValueError: Format specifier missing precision

# %%
print(f"There are {365/7:.0f} weeks in a year")
# Out:
# There are 52 weeks in a year

# %%
print(f"There are {365/7:.2f} weeks in a year")
# Out:
# There are 52.14 weeks in a year

# %%
print(f"The area of a square with side 5 cm is {2*5} cm squared.")
# Out:
# The area of a square with side 5 cm is 10 cm squared.

# %%
print(f"The house was a good size: 1200 square feet, or {1200 * 0.092903} meters squared!")
# Out:
# The house was a good size: 1200 square feet, or 111.4836 meters squared!

# %%
print(f"The house was a good size: 1200 square feet, or {1200 * 0.092903:.2f} meters squared!")
# Out:
# The house was a good size: 1200 square feet, or 111.48 meters squared!

# %%
print(" This is my first code in Python")
# Out:
#  This is my first code in Python

# %%
print ("this is the first git push")
# Out:
# this is the first git push
